# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (1.26.4)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/content/retriever-dog-picture.jpg')
print(img)
# Out:
# [[[215 232 245]
#   [216 232 245]
#   [219 232 248]
#   ...
#   [224 229 238]
#   [224 229 238]
#   [228 233 242]]
#
#  [[215 232 245]
#   [217 232 248]
#   [219 232 248]
#   ...
#   [223 228 237]
#   [224 229 238]
#   [228 233 242]]
#
#  [[216 232 248]
#   [217 232 248]
#   [219 232 248]
#   ...
#   [223 228 237]
#   [224 229 238]
#   [228 233 242]]
#
#  ...
#
#  [[ 18  28  46]
#   [ 19  26  45]
#   [ 19  27  44]
#   ...
#   [ 14  27  43]
#   [ 15  28  44]
#   [ 16  28  46]]
#
#  [[ 16  30  49]
#   [ 14  28  47]
#   [ 13  27  46]
#   ...
#   [ 12  26  44]
#   [ 13  27  45]
#   [ 15  29  47]]
#
#  [[ 37  60  82]
#   [ 34  57  79]
#   [ 31  54  76]
#   ...
#   [ 29  46  65]
#   [ 30  47  66]
#   [ 31  48  67]]]

# %%
plt.imshow(img)
plt.show()

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')  # Specify the color map as 'gray'
plt.show()

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot()
ax.imshow(img_rgb)
ax.set_title("Image")
plt.show()

# %%
resized = cv2.resize(img_rgb, (300, 300))

# %%
lined_img= img_rgb.copy()
cv2.circle(lined_img, (1200, 1200), 400, (0, 0, 255), -1)
cv2.rectangle(lined_img, (600, 600), (1600, 1600), (0, 255, 0), 3)
cv2.line(lined_img, (500, 800), (1200, 800), (255, 0, 0), 4)
plt.imshow(lined_img)
plt.show()

# %% [markdown]
# modify the coordinates

# %%
plt.imshow(img_rgb[:2500,1000:2500])

# %%
image = img_rgb.copy()
bright_incr = 100

plt.imshow(image)
plt.show()
height = image.shape[0]
width = image.shape[1]
for i in range(height):
    for j in range(width):
        for k in range(3):
            image[i][j][k]=min(image[i][j][k]+bright_incr,255)
plt.imshow(image)

# Inbuilt Function
brightened_image = cv2.add(image, bright_incr)

# %%
image = img_rgb.copy()
bright_dec = 100

plt.imshow(image)
plt.show()

for i in range(height):
    for j in range(width):
        for k in range(3):
            image[i][j][k]=max(image[i][j][k]-bright_incr,0)
plt.imshow(image)

# Inbuilt Function
contrasted_image = cv2.subtract(image, bright_dec)

# %% [markdown]
# **SIMPLE BLUR**

# %%
image =img_rgb.copy()
for i in range(1,height-1):
    for j in range(1,width-1):
        for k in range(3):
            image[i][j][k]=np.average(image[i-1:i+2,j-1:j+2,k])
plt.imshow(image)

# %%
blurred_image = cv2.blur(image, (50, 50))
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title("Simple Blurred Image")
plt.show()

# %% [markdown]
# **GAUSSIAN BLUR**

# %%
arr = np.array([[1,2,1],[2,4,2],[1,2,1]])
arr = arr / arr.sum()
image =img_rgb.copy()

for i in range(1, height-1):
    for j in range(1, width-1):
        for k in range(3):
            region = image[i-1:i+2, j-1:j+2, k]
            image[i, j, k] = np.sum(region * arr)

plt.imshow(image)

# %%
image =img_rgb.copy()

# %%
blurred_image_gau = cv2.GaussianBlur(image, (31, 31),20)
plt.imshow(cv2.cvtColor(blurred_image_gau, cv2.COLOR_BGR2RGB))
plt.title("Gaussian Blurred Image")
plt.show()
